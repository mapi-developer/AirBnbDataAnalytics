# %%
import pandas as pd

df_calendar = pd.read_csv('datasets/raw/calendar.csv')
df_listings = pd.read_csv('datasets/raw/listings.csv')
df_reviews = pd.read_csv('datasets/raw/reviews.csv')
df_calendar['price'] = df_calendar['price'].str.replace('[$,]', '', regex=True).astype(float)

# %%
df = pd.read_csv('datasets/raw/paris_calendar.csv')

df.tail(n=20)
# Out:
#       listing_id        date  vacant_days  reserved_days  occupancy  revenue  \
# 3247      474725  2026-09-01           30              0        0.0      0.0
# 3248      474725  2026-10-01           31              0        0.0      0.0
# 3249      474725  2026-11-01           30              0        0.0      0.0
# 3250      474725  2026-12-01           31              0        0.0      0.0
# 3251      474725  2027-01-01           31              0        0.0      0.0
#
#       rate_avg  booked_rate_avg  booking_lead_time_avg  length_of_stay_avg  \
# 3247     581.9              NaN                    NaN                 NaN
# 3248     569.3              NaN                    NaN                 NaN
# 3249     581.4              NaN                    NaN                 NaN
# 3250     572.2              NaN                    NaN                 NaN
# 3251     590.4              NaN                    NaN                 NaN
#
# ...
